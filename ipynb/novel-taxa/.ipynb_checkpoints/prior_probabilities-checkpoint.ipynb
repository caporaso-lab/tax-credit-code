# %% [markdown]
# # Prior Probabilities
#
# This notebook describes how to generate and use prior probability compositions to train ``q2-feature-classifier`` for taxonomic classification of marker-gene sequence data.
#
# Prior probabilities are used by some classification methods to predict the likelihood that a given class label will be observed in a population. Training prior probabilities may improve classification accuracy, particularly in situations when specific taxa are unique to an environment. This is opposed to the use of a uniform prior, which assumes that any class is equally likely to be observed in a given environment. While this is a prudent approach when handling unknown samples, it is a naive approach when handling samples from previously characterized sample types.
#
# This notebook serves two functions:
#
#     1) generating prior probability trainers to train ``q2-feature-classifier``.
#     2) comparing classification accuracy of training classifiers with:
#         a) a uniform prior.
#         b) prior probabilities appropriate for sample type X.
#         c) prior probabilities inappropriate for sample type X.
#
# This notebook examines the effect of prior probabilities in classifying two different types of data sets:
#
#     1) simulated communities generated from observed compositions of natural communities.
#     2) natural communities in which the true composition is unknown, but well studied.
#
# The general approach is to:
#
#     1) Select an appropriate natural community (NC).
#     2) Generate prior probability training set as a function of NC taxonomic composition at levels 1-6.
#     3) Select an appropriate reference dataset (RD).
#     4) extract RD sequences x,y,z (match NC taxonomies x,y,z)
#     5) mix x,y,z at defined distributions D to make simulated community S
#     6) provide prior distributions to classifier C
#     7) assign taxonomy to S using C

# %%
from os.path import join, expandvars 

from qiime.plugins import feature_classifier, taxa
from qiime import Artifact
#from tax_credit.process_mocks import *

import pandas as pd

# %%
# Project directory
project_dir = expandvars("$HOME/Desktop/projects/short-read-tax-assignment")
# Directory containing reference sequence databases
reference_database_dir = expandvars("$HOME/Desktop/ref_dbs/")
# prior probabilities directory
prior_probabilities_dir = join(project_dir, "data", "prior_probabilities")

# %% [markdown]
# ## Generating prior probabilities from natural community observations
# This section describes how we generate prior probability trainers. To do so, we use taxonomic composition observations from previously analyzed natural communities. This does introduces bias in that we are assuming that those previous observations are accurate — or at least precise enough that we can assume that training with this prior probability will yield better predictive accuracy than a uniform prior.
#
# This can be performed on any sample type and used for subsequent analysis of samples, or re-analysis of the same samples. Samples should be well-characterized and the microbial composition reasonably well-known. For this reason, we demonstrate using three defined sample types from the following data sets. Each is publicly available, with hyperlinks to the QIITA study and open-access publications below.
#
# [Wine fermentation microbiota (bacterial 16S)](https://qiita.ucsd.edu/study/description/10119)    ([Bokulich et al. mBio 2016](http://dx.doi.org/10.1128/mBio.00631-16))
#
# [Sour beer fermentation microbiota (bacterial 16S)](https://qiita.ucsd.edu/study/description/1689)    ([Bokulich et al. PLoS One 2012](http://dx.doi.org/10.1371/journal.pone.0035507))
#
# ["Moving pictures of the human microbiome" (human feces bacterial 16S)](https://qiita.ucsd.edu/study/description/550)     ([Caporaso et al. Genome Biol 2012](http://dx.doi.org/10.1186/gb-2011-12-5-r50))
#
# Download the taxonomy-annotated biom files and mapping files and place in a single directory, which we designate as natural_community_dir below. It is critical that only one sample type is used to make each prior. Hence, any dissimilar sample types must be removed prior to classification. For example, the "Moving Pictures" dataset contains samples from several body sites, but we want to focus on stool samples here.
#
# (Note that QIITA uses different processing parameters from those used in the original studies, and thus results may differ slightly from those in publication. QIITA conveniently provides pre-processed data, such that taxonomy assignments can be immediately produced from multiple studies, facilitating the training of prior probabilities.)

# %%
# Select an appropriate natural community (NC).
# Directory containing natural community observations (taxonomy assignments)
natural_community_dir = expandvars("$HOME/Desktop/projects/natural_community_priors/")

# Create dictionary that maps datasets to their biom and mapping files, and to the marker gene type
# {dataset : (db, biom_table, rep_seqs, metadata_map)}
natural_datasets = {
 #'moving_pics' : ('gg_13_8_otus', '67_otu_table.biom',
 # '550_prep_72_qiime_20160804-161109.txt'), # Moving pictures
 #'sour_beer' : ('gg_13_8_otus',
 #               join(natural_community_dir, 'beer-final.only-16s.biom'), # https://qiita.ucsd.edu/download/95214
 #               join(natural_community_dir, 'beer-final.seqs.fa.no_artifacts'), # https://qiita.ucsd.edu/download/95213
 #               join(natural_community_dir, '1989_prep_698_qiime_20150818-225324.txt')), # https://qiita.ucsd.edu/download/25875
 'wine' : ('gg_13_8_otus',
           join(natural_community_dir, 'wine-final.only-16s.biom'), # https://qiita.ucsd.edu/download/102065
           join(natural_community_dir, 'wine-final.seqs.fa.no_artifacts'), # https://qiita.ucsd.edu/download/102064
           join(natural_community_dir, '10119_prep_258_qiime_20160529-140847.txt')), # https://qiita.ucsd.edu/download/69224
}

# Set paths to reference database seqs, taxonomy, and trained classifiers
# {db : (reference_seqs, reference_tax, classifier_path)}
reference_dbs = {'gg_13_8_otus' : (join(reference_database_dir, 
                                        'gg_13_8_otus/rep_set/97_otus_515f-806r_trim250.fasta'), 
                                   join(reference_database_dir, 
                                        'gg_13_8_otus/taxonomy/97_otu_taxonomy.txt'),
                                   expandvars("$HOME/Desktop/tools/gg-13-8-99-515-806-nb-classifier.qza"))
                }

# %%
feature_classifier.methods.classify.signature
# Out:
# reads : (FeatureData[Sequence], <class 'q2_types.feature_data._transformer.DNAIterator'>), classifier : (TaxonomicClassifier, <class 'dict'>), chunk_size : (Int, <class 'int'>), n_jobs : (Int, <class 'int'>), pre_dispatch : (Str, <class 'str'>), confidence : (Float, <class 'float'>) -> ((FeatureData[Taxonomy], <class 'pandas.core.frame.DataFrame'>),)

# %%
df = pd.DataFrame.from_csv(join(natural_community_dir, '10119_prep_258_qiime_20160529-140847.txt'), sep='\t')
df
# Out:
#              BarcodeSequence LinkerPrimerSequence center_name  \
# #SampleID
# 10119.MT.283        CGATTACG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.282        CACTGTCT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.281        CAGAGACA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.280        CAGTCACA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.287        CATCAGCA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.286        CATCTGGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.285        CATGTCCT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.289        CAGAGAGT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.288        CAGTCAGT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.840        GCTATTCC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.218        AGTCCAGT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.219        AGTCCACA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.353        GCGCTATA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.355        GCAATTCG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.354        GCATTACG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.357        TAGGAACG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.356        TCACACTC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.359        TACCTAGG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.211        AGAGTCAG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.212        AGAGACAC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.213        ATGCATGC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.214        ATCGATGC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.443        CACTCAGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.216        AGTGACTC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.217        GCATGGAA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.334        GTCAGTCA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.833        GCGGTTAT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.804        GATGTCGT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.445        TACGAAGG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.332        GTGACAGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# ...                      ...                  ...         ...
# 10119.MT.740        TCTGACTC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.812        GATGTGGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.813        GTAGCTAC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.801        GCGCTTAA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.810        GCCGAATT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.763        GACATCAC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.97         ACAGCAGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.96         ACGAAGCA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.95         ACGATGGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.94         ACGTTCCT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.89         ACAGCACT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.92         ACTGCTCT  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.678        GAGTACAG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.679        GAGAAGTC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.676        GATCGATC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.677        GAGTTCTG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.674        CTGTGTGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.675        GATGCATC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.673        GACAGACA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.670        GACTCACA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.574        CTAGCTTC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.800        GCTAGCTA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.99         AGACCAGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.768        GAGTCAGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.579        CTGTACAG  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.578        CGGCTATA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.320        TAGGCGAA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.98         ACACCTGA  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.802        GCATTAGC  GTGCCAGCMGCCGCGGTAA      UCDAES
# 10119.MT.321        TAGCGCAT  GTGCCAGCMGCCGCGGTAA      UCDAES
#
#                                             center_project_name  \
# #SampleID
# 10119.MT.283  Microbiota of regional grapes and wine ferment...
# 10119.MT.282  Microbiota of regional grapes and wine ferment...
# 10119.MT.281  Microbiota of regional grapes and wine ferment...
# 10119.MT.280  Microbiota of regional grapes and wine ferment...
# 10119.MT.287  Microbiota of regional grapes and wine ferment...
# 10119.MT.286  Microbiota of regional grapes and wine ferment...
# 10119.MT.285  Microbiota of regional grapes and wine ferment...
# 10119.MT.289  Microbiota of regional grapes and wine ferment...
# 10119.MT.288  Microbiota of regional grapes and wine ferment...
# 10119.MT.840  Microbiota of regional grapes and wine ferment...
# 10119.MT.218  Microbiota of regional grapes and wine ferment...
# 10119.MT.219  Microbiota of regional grapes and wine ferment...
# 10119.MT.353  Microbiota of regional grapes and wine ferment...
# 10119.MT.355  Microbiota of regional grapes and wine ferment...
# 10119.MT.354  Microbiota of regional grapes and wine ferment...
# 10119.MT.357  Microbiota of regional grapes and wine ferment...
# 10119.MT.356  Microbiota of regional grapes and wine ferment...
# 10119.MT.359  Microbiota of regional grapes and wine ferment...
# 10119.MT.211  Microbiota of regional grapes and wine ferment...
# 10119.MT.212  Microbiota of regional grapes and wine ferment...
# 10119.MT.213  Microbiota of regional grapes and wine ferment...
# 10119.MT.214  Microbiota of regional grapes and wine ferment...
# 10119.MT.443  Microbiota of regional grapes and wine ferment...
# 10119.MT.216  Microbiota of regional grapes and wine ferment...
# 10119.MT.217  Microbiota of regional grapes and wine ferment...
# 10119.MT.334  Microbiota of regional grapes and wine ferment...
# 10119.MT.833  Microbiota of regional grapes and wine ferment...
# 10119.MT.804  Microbiota of regional grapes and wine ferment...
# 10119.MT.445  Microbiota of regional grapes and wine ferment...
# 10119.MT.332  Microbiota of regional grapes and wine ferment...
# ...                                                         ...
# 10119.MT.740  Microbiota of regional grapes and wine ferment...
# 10119.MT.812  Microbiota of regional grapes and wine ferment...
# 10119.MT.813  Microbiota of regional grapes and wine ferment...
# 10119.MT.801  Microbiota of regional grapes and wine ferment...
# 10119.MT.810  Microbiota of regional grapes and wine ferment...
# 10119.MT.763  Microbiota of regional grapes and wine ferment...
# 10119.MT.97   Microbiota of regional grapes and wine ferment...
# 10119.MT.96   Microbiota of regional grapes and wine ferment...
# 10119.MT.95   Microbiota of regional grapes and wine ferment...
# 10119.MT.94   Microbiota of regional grapes and wine ferment...
# 10119.MT.89   Microbiota of regional grapes and wine ferment...
# 10119.MT.92   Microbiota of regional grapes and wine ferment...
# 10119.MT.678  Microbiota of regional grapes and wine ferment...
# 10119.MT.679  Microbiota of regional grapes and wine ferment...
# 10119.MT.676  Microbiota of regional grapes and wine ferment...
# 10119.MT.677  Microbiota of regional grapes and wine ferment...
# 10119.MT.674  Microbiota of regional grapes and wine ferment...
# 10119.MT.675  Microbiota of regional grapes and wine ferment...
# 10119.MT.673  Microbiota of regional grapes and wine ferment...
# 10119.MT.670  Microbiota of regional grapes and wine ferment...
# 10119.MT.574  Microbiota of regional grapes and wine ferment...
# 10119.MT.800  Microbiota of regional grapes and wine ferment...
# 10119.MT.99   Microbiota of regional grapes and wine ferment...
# 10119.MT.768  Microbiota of regional grapes and wine ferment...
# 10119.MT.579  Microbiota of regional grapes and wine ferment...
# 10119.MT.578  Microbiota of regional grapes and wine ferment...
# 10119.MT.320  Microbiota of regional grapes and wine ferment...
# 10119.MT.98   Microbiota of regional grapes and wine ferment...
# 10119.MT.802  Microbiota of regional grapes and wine ferment...
# 10119.MT.321  Microbiota of regional grapes and wine ferment...
#
#                  emp_status experiment_center  \
# #SampleID
# 10119.MT.283  EMP_Processed           UCDCAES
# 10119.MT.282  EMP_Processed           UCDCAES
# 10119.MT.281  EMP_Processed           UCDCAES
# 10119.MT.280  EMP_Processed           UCDCAES
# 10119.MT.287  EMP_Processed           UCDCAES
# 10119.MT.286  EMP_Processed           UCDCAES
# 10119.MT.285  EMP_Processed           UCDCAES
# 10119.MT.289  EMP_Processed           UCDCAES
# 10119.MT.288  EMP_Processed           UCDCAES
# 10119.MT.840  EMP_Processed           UCDCAES
# 10119.MT.218  EMP_Processed           UCDCAES
# 10119.MT.219  EMP_Processed           UCDCAES
# 10119.MT.353  EMP_Processed           UCDCAES
# 10119.MT.355  EMP_Processed           UCDCAES
# 10119.MT.354  EMP_Processed           UCDCAES
# 10119.MT.357  EMP_Processed           UCDCAES
# 10119.MT.356  EMP_Processed           UCDCAES
# 10119.MT.359  EMP_Processed           UCDCAES
# 10119.MT.211  EMP_Processed           UCDCAES
# 10119.MT.212  EMP_Processed           UCDCAES
# 10119.MT.213  EMP_Processed           UCDCAES
# 10119.MT.214  EMP_Processed           UCDCAES
# 10119.MT.443  EMP_Processed           UCDCAES
# 10119.MT.216  EMP_Processed           UCDCAES
# 10119.MT.217  EMP_Processed           UCDCAES
# 10119.MT.334  EMP_Processed           UCDCAES
# 10119.MT.833  EMP_Processed           UCDCAES
# 10119.MT.804  EMP_Processed           UCDCAES
# 10119.MT.445  EMP_Processed           UCDCAES
# 10119.MT.332  EMP_Processed           UCDCAES
# ...                     ...               ...
# 10119.MT.740  EMP_Processed           UCDCAES
# 10119.MT.812  EMP_Processed           UCDCAES
# 10119.MT.813  EMP_Processed           UCDCAES
# 10119.MT.801  EMP_Processed           UCDCAES
# 10119.MT.810  EMP_Processed           UCDCAES
# 10119.MT.763  EMP_Processed           UCDCAES
# 10119.MT.97   EMP_Processed           UCDCAES
# 10119.MT.96   EMP_Processed           UCDCAES
# 10119.MT.95   EMP_Processed           UCDCAES
# 10119.MT.94   EMP_Processed           UCDCAES
# 10119.MT.89   EMP_Processed           UCDCAES
# 10119.MT.92   EMP_Processed           UCDCAES
# 10119.MT.678  EMP_Processed           UCDCAES
# 10119.MT.679  EMP_Processed           UCDCAES
# 10119.MT.676  EMP_Processed           UCDCAES
# 10119.MT.677  EMP_Processed           UCDCAES
# 10119.MT.674  EMP_Processed           UCDCAES
# 10119.MT.675  EMP_Processed           UCDCAES
# 10119.MT.673  EMP_Processed           UCDCAES
# 10119.MT.670  EMP_Processed           UCDCAES
# 10119.MT.574  EMP_Processed           UCDCAES
# 10119.MT.800  EMP_Processed           UCDCAES
# 10119.MT.99   EMP_Processed           UCDCAES
# 10119.MT.768  EMP_Processed           UCDCAES
# 10119.MT.579  EMP_Processed           UCDCAES
# 10119.MT.578  EMP_Processed           UCDCAES
# 10119.MT.320  EMP_Processed           UCDCAES
# 10119.MT.98   EMP_Processed           UCDCAES
# 10119.MT.802  EMP_Processed           UCDCAES
# 10119.MT.321  EMP_Processed           UCDCAES
#
#                                   experiment_design_description  \
# #SampleID
# 10119.MT.283  Microbiota of regional grapes and wine ferment...
# 10119.MT.282  Microbiota of regional grapes and wine ferment...
# 10119.MT.281  Microbiota of regional grapes and wine ferment...
# 10119.MT.280  Microbiota of regional grapes and wine ferment...
# 10119.MT.287  Microbiota of regional grapes and wine ferment...
# 10119.MT.286  Microbiota of regional grapes and wine ferment...
# 10119.MT.285  Microbiota of regional grapes and wine ferment...
# 10119.MT.289  Microbiota of regional grapes and wine ferment...
# 10119.MT.288  Microbiota of regional grapes and wine ferment...
# 10119.MT.840  Microbiota of regional grapes and wine ferment...
# 10119.MT.218  Microbiota of regional grapes and wine ferment...
# 10119.MT.219  Microbiota of regional grapes and wine ferment...
# 10119.MT.353  Microbiota of regional grapes and wine ferment...
# 10119.MT.355  Microbiota of regional grapes and wine ferment...
# 10119.MT.354  Microbiota of regional grapes and wine ferment...
# 10119.MT.357  Microbiota of regional grapes and wine ferment...
# 10119.MT.356  Microbiota of regional grapes and wine ferment...
# 10119.MT.359  Microbiota of regional grapes and wine ferment...
# 10119.MT.211  Microbiota of regional grapes and wine ferment...
# 10119.MT.212  Microbiota of regional grapes and wine ferment...
# 10119.MT.213  Microbiota of regional grapes and wine ferment...
# 10119.MT.214  Microbiota of regional grapes and wine ferment...
# 10119.MT.443  Microbiota of regional grapes and wine ferment...
# 10119.MT.216  Microbiota of regional grapes and wine ferment...
# 10119.MT.217  Microbiota of regional grapes and wine ferment...
# 10119.MT.334  Microbiota of regional grapes and wine ferment...
# 10119.MT.833  Microbiota of regional grapes and wine ferment...
# 10119.MT.804  Microbiota of regional grapes and wine ferment...
# 10119.MT.445  Microbiota of regional grapes and wine ferment...
# 10119.MT.332  Microbiota of regional grapes and wine ferment...
# ...                                                         ...
# 10119.MT.740  Microbiota of regional grapes and wine ferment...
# 10119.MT.812  Microbiota of regional grapes and wine ferment...
# 10119.MT.813  Microbiota of regional grapes and wine ferment...
# 10119.MT.801  Microbiota of regional grapes and wine ferment...
# 10119.MT.810  Microbiota of regional grapes and wine ferment...
# 10119.MT.763  Microbiota of regional grapes and wine ferment...
# 10119.MT.97   Microbiota of regional grapes and wine ferment...
# 10119.MT.96   Microbiota of regional grapes and wine ferment...
# 10119.MT.95   Microbiota of regional grapes and wine ferment...
# 10119.MT.94   Microbiota of regional grapes and wine ferment...
# 10119.MT.89   Microbiota of regional grapes and wine ferment...
# 10119.MT.92   Microbiota of regional grapes and wine ferment...
# 10119.MT.678  Microbiota of regional grapes and wine ferment...
# 10119.MT.679  Microbiota of regional grapes and wine ferment...
# 10119.MT.676  Microbiota of regional grapes and wine ferment...
# 10119.MT.677  Microbiota of regional grapes and wine ferment...
# 10119.MT.674  Microbiota of regional grapes and wine ferment...
# 10119.MT.675  Microbiota of regional grapes and wine ferment...
# 10119.MT.673  Microbiota of regional grapes and wine ferment...
# 10119.MT.670  Microbiota of regional grapes and wine ferment...
# 10119.MT.574  Microbiota of regional grapes and wine ferment...
# 10119.MT.800  Microbiota of regional grapes and wine ferment...
# 10119.MT.99   Microbiota of regional grapes and wine ferment...
# 10119.MT.768  Microbiota of regional grapes and wine ferment...
# 10119.MT.579  Microbiota of regional grapes and wine ferment...
# 10119.MT.578  Microbiota of regional grapes and wine ferment...
# 10119.MT.320  Microbiota of regional grapes and wine ferment...
# 10119.MT.98   Microbiota of regional grapes and wine ferment...
# 10119.MT.802  Microbiota of regional grapes and wine ferment...
# 10119.MT.321  Microbiota of regional grapes and wine ferment...
#
#                                                experiment_title  \
# #SampleID
# 10119.MT.283  Microbiota of regional grapes and wine ferment...
# 10119.MT.282  Microbiota of regional grapes and wine ferment...
# 10119.MT.281  Microbiota of regional grapes and wine ferment...
# 10119.MT.280  Microbiota of regional grapes and wine ferment...
# 10119.MT.287  Microbiota of regional grapes and wine ferment...
# 10119.MT.286  Microbiota of regional grapes and wine ferment...
# 10119.MT.285  Microbiota of regional grapes and wine ferment...
# 10119.MT.289  Microbiota of regional grapes and wine ferment...
# 10119.MT.288  Microbiota of regional grapes and wine ferment...
# 10119.MT.840  Microbiota of regional grapes and wine ferment...
# 10119.MT.218  Microbiota of regional grapes and wine ferment...
# 10119.MT.219  Microbiota of regional grapes and wine ferment...
# 10119.MT.353  Microbiota of regional grapes and wine ferment...
# 10119.MT.355  Microbiota of regional grapes and wine ferment...
# 10119.MT.354  Microbiota of regional grapes and wine ferment...
# 10119.MT.357  Microbiota of regional grapes and wine ferment...
# 10119.MT.356  Microbiota of regional grapes and wine ferment...
# 10119.MT.359  Microbiota of regional grapes and wine ferment...
# 10119.MT.211  Microbiota of regional grapes and wine ferment...
# 10119.MT.212  Microbiota of regional grapes and wine ferment...
# 10119.MT.213  Microbiota of regional grapes and wine ferment...
# 10119.MT.214  Microbiota of regional grapes and wine ferment...
# 10119.MT.443  Microbiota of regional grapes and wine ferment...
# 10119.MT.216  Microbiota of regional grapes and wine ferment...
# 10119.MT.217  Microbiota of regional grapes and wine ferment...
# 10119.MT.334  Microbiota of regional grapes and wine ferment...
# 10119.MT.833  Microbiota of regional grapes and wine ferment...
# 10119.MT.804  Microbiota of regional grapes and wine ferment...
# 10119.MT.445  Microbiota of regional grapes and wine ferment...
# 10119.MT.332  Microbiota of regional grapes and wine ferment...
# ...                                                         ...
# 10119.MT.740  Microbiota of regional grapes and wine ferment...
# 10119.MT.812  Microbiota of regional grapes and wine ferment...
# 10119.MT.813  Microbiota of regional grapes and wine ferment...
# 10119.MT.801  Microbiota of regional grapes and wine ferment...
# 10119.MT.810  Microbiota of regional grapes and wine ferment...
# 10119.MT.763  Microbiota of regional grapes and wine ferment...
# 10119.MT.97   Microbiota of regional grapes and wine ferment...
# 10119.MT.96   Microbiota of regional grapes and wine ferment...
# 10119.MT.95   Microbiota of regional grapes and wine ferment...
# 10119.MT.94   Microbiota of regional grapes and wine ferment...
# 10119.MT.89   Microbiota of regional grapes and wine ferment...
# 10119.MT.92   Microbiota of regional grapes and wine ferment...
# 10119.MT.678  Microbiota of regional grapes and wine ferment...
# 10119.MT.679  Microbiota of regional grapes and wine ferment...
# 10119.MT.676  Microbiota of regional grapes and wine ferment...
# 10119.MT.677  Microbiota of regional grapes and wine ferment...
# 10119.MT.674  Microbiota of regional grapes and wine ferment...
# 10119.MT.675  Microbiota of regional grapes and wine ferment...
# 10119.MT.673  Microbiota of regional grapes and wine ferment...
# 10119.MT.670  Microbiota of regional grapes and wine ferment...
# 10119.MT.574  Microbiota of regional grapes and wine ferment...
# 10119.MT.800  Microbiota of regional grapes and wine ferment...
# 10119.MT.99   Microbiota of regional grapes and wine ferment...
# 10119.MT.768  Microbiota of regional grapes and wine ferment...
# 10119.MT.579  Microbiota of regional grapes and wine ferment...
# 10119.MT.578  Microbiota of regional grapes and wine ferment...
# 10119.MT.320  Microbiota of regional grapes and wine ferment...
# 10119.MT.98   Microbiota of regional grapes and wine ferment...
# 10119.MT.802  Microbiota of regional grapes and wine ferment...
# 10119.MT.321  Microbiota of regional grapes and wine ferment...
#
#              illumina_technology instrument_model     ...     sample_tube_id  \
# #SampleID                                             ...
# 10119.MT.283               MiSeq   Illumina MiSeq     ...             MT.283
# 10119.MT.282               MiSeq   Illumina MiSeq     ...             MT.282
# 10119.MT.281               MiSeq   Illumina MiSeq     ...             MT.281
# 10119.MT.280               MiSeq   Illumina MiSeq     ...             MT.280
# 10119.MT.287               MiSeq   Illumina MiSeq     ...             MT.287
# 10119.MT.286               MiSeq   Illumina MiSeq     ...             MT.286
# 10119.MT.285               MiSeq   Illumina MiSeq     ...             MT.285
# 10119.MT.289               MiSeq   Illumina MiSeq     ...             MT.289
# 10119.MT.288               MiSeq   Illumina MiSeq     ...             MT.288
# 10119.MT.840               MiSeq   Illumina MiSeq     ...             MT.840
# 10119.MT.218               MiSeq   Illumina MiSeq     ...             MT.218
# 10119.MT.219               MiSeq   Illumina MiSeq     ...             MT.219
# 10119.MT.353               MiSeq   Illumina MiSeq     ...             MT.353
# 10119.MT.355               MiSeq   Illumina MiSeq     ...             MT.355
# 10119.MT.354               MiSeq   Illumina MiSeq     ...             MT.354
# 10119.MT.357               MiSeq   Illumina MiSeq     ...             MT.357
# 10119.MT.356               MiSeq   Illumina MiSeq     ...             MT.356
# 10119.MT.359               MiSeq   Illumina MiSeq     ...             MT.359
# 10119.MT.211               MiSeq   Illumina MiSeq     ...             MT.211
# 10119.MT.212               MiSeq   Illumina MiSeq     ...             MT.212
# 10119.MT.213               MiSeq   Illumina MiSeq     ...             MT.213
# 10119.MT.214               MiSeq   Illumina MiSeq     ...             MT.214
# 10119.MT.443               MiSeq   Illumina MiSeq     ...             MT.443
# 10119.MT.216               MiSeq   Illumina MiSeq     ...             MT.216
# 10119.MT.217               MiSeq   Illumina MiSeq     ...             MT.217
# 10119.MT.334               MiSeq   Illumina MiSeq     ...             MT.334
# 10119.MT.833               MiSeq   Illumina MiSeq     ...             MT.833
# 10119.MT.804               MiSeq   Illumina MiSeq     ...             MT.804
# 10119.MT.445               MiSeq   Illumina MiSeq     ...             MT.445
# 10119.MT.332               MiSeq   Illumina MiSeq     ...             MT.332
# ...                          ...              ...     ...                ...
# 10119.MT.740               MiSeq   Illumina MiSeq     ...             MT.740
# 10119.MT.812               MiSeq   Illumina MiSeq     ...             MT.812
# 10119.MT.813               MiSeq   Illumina MiSeq     ...             MT.813
# 10119.MT.801               MiSeq   Illumina MiSeq     ...             MT.801
# 10119.MT.810               MiSeq   Illumina MiSeq     ...             MT.810
# 10119.MT.763               MiSeq   Illumina MiSeq     ...             MT.763
# 10119.MT.97                MiSeq   Illumina MiSeq     ...              MT.97
# 10119.MT.96                MiSeq   Illumina MiSeq     ...              MT.96
# 10119.MT.95                MiSeq   Illumina MiSeq     ...              MT.95
# 10119.MT.94                MiSeq   Illumina MiSeq     ...              MT.94
# 10119.MT.89                MiSeq   Illumina MiSeq     ...              MT.89
# 10119.MT.92                MiSeq   Illumina MiSeq     ...              MT.92
# 10119.MT.678               MiSeq   Illumina MiSeq     ...             MT.678
# 10119.MT.679               MiSeq   Illumina MiSeq     ...             MT.679
# 10119.MT.676               MiSeq   Illumina MiSeq     ...             MT.676
# 10119.MT.677               MiSeq   Illumina MiSeq     ...             MT.677
# 10119.MT.674               MiSeq   Illumina MiSeq     ...             MT.674
# 10119.MT.675               MiSeq   Illumina MiSeq     ...             MT.675
# 10119.MT.673               MiSeq   Illumina MiSeq     ...             MT.673
# 10119.MT.670               MiSeq   Illumina MiSeq     ...             MT.670
# 10119.MT.574               MiSeq   Illumina MiSeq     ...             MT.574
# 10119.MT.800               MiSeq   Illumina MiSeq     ...             MT.800
# 10119.MT.99                MiSeq   Illumina MiSeq     ...              MT.99
# 10119.MT.768               MiSeq   Illumina MiSeq     ...             MT.768
# 10119.MT.579               MiSeq   Illumina MiSeq     ...             MT.579
# 10119.MT.578               MiSeq   Illumina MiSeq     ...             MT.578
# 10119.MT.320               MiSeq   Illumina MiSeq     ...             MT.320
# 10119.MT.98                MiSeq   Illumina MiSeq     ...              MT.98
# 10119.MT.802               MiSeq   Illumina MiSeq     ...             MT.802
# 10119.MT.321               MiSeq   Illumina MiSeq     ...             MT.321
#
#              sample_type  scientific_name stage taxon_id  \
# #SampleID
# 10119.MT.283        must  food metagenome     B   870726
# 10119.MT.282        must  food metagenome     B   870726
# 10119.MT.281        must  food metagenome     B   870726
# 10119.MT.280        must  food metagenome     B   870726
# 10119.MT.287        must  food metagenome     B   870726
# 10119.MT.286        wine  food metagenome     D   870726
# 10119.MT.285        wine  food metagenome     D   870726
# 10119.MT.289        wine  food metagenome     D   870726
# 10119.MT.288        must  food metagenome     B   870726
# 10119.MT.840        wine  food metagenome     G   870726
# 10119.MT.218        wine  food metagenome     F   870726
# 10119.MT.219        wine  food metagenome     F   870726
# 10119.MT.353        wine  food metagenome     E   870726
# 10119.MT.355        wine  food metagenome     F   870726
# 10119.MT.354        wine  food metagenome     F   870726
# 10119.MT.357        wine  food metagenome     F   870726
# 10119.MT.356        wine  food metagenome     F   870726
# 10119.MT.359        wine  food metagenome     E   870726
# 10119.MT.211        wine  food metagenome     F   870726
# 10119.MT.212        wine  food metagenome     F   870726
# 10119.MT.213        wine  food metagenome     F   870726
# 10119.MT.214        wine  food metagenome     F   870726
# 10119.MT.443        must  food metagenome     B   870726
# 10119.MT.216        wine  food metagenome     F   870726
# 10119.MT.217        wine  food metagenome     F   870726
# 10119.MT.334        must  food metagenome     A   870726
# 10119.MT.833        wine  food metagenome     G   870726
# 10119.MT.804        wine  food metagenome     H   870726
# 10119.MT.445        must  food metagenome     B   870726
# 10119.MT.332        must  food metagenome     A   870726
# ...                  ...              ...   ...      ...
# 10119.MT.740        wine  food metagenome     G   870726
# 10119.MT.812        wine  food metagenome     H   870726
# 10119.MT.813        wine  food metagenome     H   870726
# 10119.MT.801        wine  food metagenome     H   870726
# 10119.MT.810        wine  food metagenome     H   870726
# 10119.MT.763        wine  food metagenome     F   870726
# 10119.MT.97         wine  food metagenome     F   870726
# 10119.MT.96         wine  food metagenome     F   870726
# 10119.MT.95         wine  food metagenome     F   870726
# 10119.MT.94         wine  food metagenome     F   870726
# 10119.MT.89         wine  food metagenome     F   870726
# 10119.MT.92         wine  food metagenome     F   870726
# 10119.MT.678        must  food metagenome     A   870726
# 10119.MT.679        must  food metagenome     A   870726
# 10119.MT.676        must  food metagenome     A   870726
# 10119.MT.677        must  food metagenome     A   870726
# 10119.MT.674        must  food metagenome     B   870726
# 10119.MT.675        must  food metagenome     B   870726
# 10119.MT.673        must  food metagenome     B   870726
# 10119.MT.670        must  food metagenome     A   870726
# 10119.MT.574        wine  food metagenome     E   870726
# 10119.MT.800        wine  food metagenome     H   870726
# 10119.MT.99         wine  food metagenome     F   870726
# 10119.MT.768        wine  food metagenome     F   870726
# 10119.MT.579        must  food metagenome     A   870726
# 10119.MT.578        must  food metagenome     A   870726
# 10119.MT.320        must  food metagenome     B   870726
# 10119.MT.98         wine  food metagenome     F   870726
# 10119.MT.802        wine  food metagenome     G   870726
# 10119.MT.321        must  food metagenome     A   870726
#
#                                                           title  \
# #SampleID
# 10119.MT.283  Microbiota of regional grapes and wine ferment...
# 10119.MT.282  Microbiota of regional grapes and wine ferment...
# 10119.MT.281  Microbiota of regional grapes and wine ferment...
# 10119.MT.280  Microbiota of regional grapes and wine ferment...
# 10119.MT.287  Microbiota of regional grapes and wine ferment...
# 10119.MT.286  Microbiota of regional grapes and wine ferment...
# 10119.MT.285  Microbiota of regional grapes and wine ferment...
# 10119.MT.289  Microbiota of regional grapes and wine ferment...
# 10119.MT.288  Microbiota of regional grapes and wine ferment...
# 10119.MT.840  Microbiota of regional grapes and wine ferment...
# 10119.MT.218  Microbiota of regional grapes and wine ferment...
# 10119.MT.219  Microbiota of regional grapes and wine ferment...
# 10119.MT.353  Microbiota of regional grapes and wine ferment...
# 10119.MT.355  Microbiota of regional grapes and wine ferment...
# 10119.MT.354  Microbiota of regional grapes and wine ferment...
# 10119.MT.357  Microbiota of regional grapes and wine ferment...
# 10119.MT.356  Microbiota of regional grapes and wine ferment...
# 10119.MT.359  Microbiota of regional grapes and wine ferment...
# 10119.MT.211  Microbiota of regional grapes and wine ferment...
# 10119.MT.212  Microbiota of regional grapes and wine ferment...
# 10119.MT.213  Microbiota of regional grapes and wine ferment...
# 10119.MT.214  Microbiota of regional grapes and wine ferment...
# 10119.MT.443  Microbiota of regional grapes and wine ferment...
# 10119.MT.216  Microbiota of regional grapes and wine ferment...
# 10119.MT.217  Microbiota of regional grapes and wine ferment...
# 10119.MT.334  Microbiota of regional grapes and wine ferment...
# 10119.MT.833  Microbiota of regional grapes and wine ferment...
# 10119.MT.804  Microbiota of regional grapes and wine ferment...
# 10119.MT.445  Microbiota of regional grapes and wine ferment...
# 10119.MT.332  Microbiota of regional grapes and wine ferment...
# ...                                                         ...
# 10119.MT.740  Microbiota of regional grapes and wine ferment...
# 10119.MT.812  Microbiota of regional grapes and wine ferment...
# 10119.MT.813  Microbiota of regional grapes and wine ferment...
# 10119.MT.801  Microbiota of regional grapes and wine ferment...
# 10119.MT.810  Microbiota of regional grapes and wine ferment...
# 10119.MT.763  Microbiota of regional grapes and wine ferment...
# 10119.MT.97   Microbiota of regional grapes and wine ferment...
# 10119.MT.96   Microbiota of regional grapes and wine ferment...
# 10119.MT.95   Microbiota of regional grapes and wine ferment...
# 10119.MT.94   Microbiota of regional grapes and wine ferment...
# 10119.MT.89   Microbiota of regional grapes and wine ferment...
# 10119.MT.92   Microbiota of regional grapes and wine ferment...
# 10119.MT.678  Microbiota of regional grapes and wine ferment...
# 10119.MT.679  Microbiota of regional grapes and wine ferment...
# 10119.MT.676  Microbiota of regional grapes and wine ferment...
# 10119.MT.677  Microbiota of regional grapes and wine ferment...
# 10119.MT.674  Microbiota of regional grapes and wine ferment...
# 10119.MT.675  Microbiota of regional grapes and wine ferment...
# 10119.MT.673  Microbiota of regional grapes and wine ferment...
# 10119.MT.670  Microbiota of regional grapes and wine ferment...
# 10119.MT.574  Microbiota of regional grapes and wine ferment...
# 10119.MT.800  Microbiota of regional grapes and wine ferment...
# 10119.MT.99   Microbiota of regional grapes and wine ferment...
# 10119.MT.768  Microbiota of regional grapes and wine ferment...
# 10119.MT.579  Microbiota of regional grapes and wine ferment...
# 10119.MT.578  Microbiota of regional grapes and wine ferment...
# 10119.MT.320  Microbiota of regional grapes and wine ferment...
# 10119.MT.98   Microbiota of regional grapes and wine ferment...
# 10119.MT.802  Microbiota of regional grapes and wine ferment...
# 10119.MT.321  Microbiota of regional grapes and wine ferment...
#
#                          variety vineyard winery Description
# #SampleID
# 10119.MT.283  Cabernet_Sauvignon       21     NN      MT.283
# 10119.MT.282  Cabernet_Sauvignon       21     NN      MT.282
# 10119.MT.281              Merlot       28     NN      MT.281
# 10119.MT.280  Cabernet_Sauvignon       21     NN      MT.280
# 10119.MT.287  Cabernet_Sauvignon       21     NN      MT.287
# 10119.MT.286  Cabernet_Sauvignon       24     NN      MT.286
# 10119.MT.285  Cabernet_Sauvignon       24     NN      MT.285
# 10119.MT.289  Cabernet_Sauvignon       19     NN      MT.289
# 10119.MT.288  Cabernet_Sauvignon       21     NN      MT.288
# 10119.MT.840              Merlot       28     NN      MT.840
# 10119.MT.218          Chardonnay       12     FN      MT.218
# 10119.MT.219          Chardonnay        6     FN      MT.219
# 10119.MT.353  Cabernet_Sauvignon       21     NN      MT.353
# 10119.MT.355          Chardonnay       11     NN      MT.355
# 10119.MT.354          Chardonnay       12     NN      MT.354
# 10119.MT.357          Chardonnay       12     NN      MT.357
# 10119.MT.356          Chardonnay       11     NN      MT.356
# 10119.MT.359  Cabernet_Sauvignon       21     NN      MT.359
# 10119.MT.211          Chardonnay       12     FN      MT.211
# 10119.MT.212          Chardonnay        1     FN      MT.212
# 10119.MT.213          Chardonnay        8     FN      MT.213
# 10119.MT.214          Chardonnay        2     FN      MT.214
# 10119.MT.443               Dolce    Dolce  DOLCE      MT.443
# 10119.MT.216          Chardonnay        4     FN      MT.216
# 10119.MT.217          Chardonnay        6     FN      MT.217
# 10119.MT.334          Chardonnay        8     FN      MT.334
# 10119.MT.833  Cabernet_Sauvignon       26     NN      MT.833
# 10119.MT.804               Dolce    Dolce  DOLCE      MT.804
# 10119.MT.445  Cabernet_Sauvignon       17     NN      MT.445
# 10119.MT.332          Chardonnay        4     FN      MT.332
# ...                          ...      ...    ...         ...
# 10119.MT.740  Cabernet_Sauvignon       10     FN      MT.740
# 10119.MT.812  Cabernet_Sauvignon       10     FN      MT.812
# 10119.MT.813  Cabernet_Sauvignon       10     FN      MT.813
# 10119.MT.801               Dolce    Dolce  DOLCE      MT.801
# 10119.MT.810  Cabernet_Sauvignon       10     FN      MT.810
# 10119.MT.763               Dolce    Dolce  DOLCE      MT.763
# 10119.MT.97           Chardonnay       10     FN       MT.97
# 10119.MT.96           Chardonnay       10     FN       MT.96
# 10119.MT.95           Chardonnay        2     FN       MT.95
# 10119.MT.94           Chardonnay        2     FN       MT.94
# 10119.MT.89           Chardonnay       10     FN       MT.89
# 10119.MT.92           Chardonnay        8     FN       MT.92
# 10119.MT.678          Chardonnay        5     FN      MT.678
# 10119.MT.679          Chardonnay       10     FN      MT.679
# 10119.MT.676          Chardonnay       10     FN      MT.676
# 10119.MT.677          Chardonnay       10     FN      MT.677
# 10119.MT.674          Chardonnay       10     FN      MT.674
# 10119.MT.675          Chardonnay       10     FN      MT.675
# 10119.MT.673          Chardonnay       10     FN      MT.673
# 10119.MT.670          Chardonnay       10     FN      MT.670
# 10119.MT.574          Pinot_Noir       25     NN      MT.574
# 10119.MT.800               Dolce    Dolce  DOLCE      MT.800
# 10119.MT.99           Chardonnay        8     FN       MT.99
# 10119.MT.768               Dolce    Dolce  DOLCE      MT.768
# 10119.MT.579          Pinot_Noir       25     NN      MT.579
# 10119.MT.578          Pinot_Noir       25     NN      MT.578
# 10119.MT.320          Chardonnay        6     FN      MT.320
# 10119.MT.98           Chardonnay        8     FN       MT.98
# 10119.MT.802  Cabernet_Sauvignon       19     NN      MT.802
# 10119.MT.321          Chardonnay        4     FN      MT.321
#
# [778 rows x 62 columns]

# %%
# Generate prior probability training set as a function of NC taxonomic composition
for dataset, data in natural_datasets.items():
    db, biom_table, rep_seqs, metadata_map = data
    reference_seqs, reference_tax, classifier_path = reference_dbs[db]
    
    # import data into qiime
    feature_table = Artifact.import_data("FeatureTable[Frequency]", biom_table)
    rep_seqs_artifact = Artifact.import_data("FeatureData[Sequence]", rep_seqs)

    # assign taxonomy using uniform prior
    tax_assign = feature_classifier.methods.classify(reads = rep_seqs_artifact,
                                                     classifier = classifier_path)
    tax_assign.save(''.join(map(str, [natural_community_dir, '/', 
                                      dataset, '_tax_assignment.qza'])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-abf62e7ac1b4> in <module>()
#       6     # import data into qiime
#       7     feature_table = Artifact.import_data("FeatureTable[Frequency]", biom_table)
# ----> 8     rep_seqs_artifact = Artifact.import_data("FeatureData[Sequence]", rep_seqs)
#       9
#      10     # assign taxonomy using uniform prior
#
# /Users/nbokulich/miniconda3/envs/qiime2-06/lib/python3.5/site-packages/qiime-2.0.6-py3.5.egg/qiime/sdk/result.py in import_data(cls, type, view, view_type)
#     189
#     190         provenance_capture = archive.ImportProvenanceCapture(format_, md5sums)
# --> 191         return cls._from_view(type_, view, view_type, provenance_capture)
#     192
#     193     @classmethod
#
# /Users/nbokulich/miniconda3/envs/qiime2-06/lib/python3.5/site-packages/qiime-2.0.6-py3.5.egg/qiime/sdk/result.py in _from_view(cls, type, view, view_type, provenance_capture)
#     214         transformation = from_type.make_transformation(to_type,
#     215                                                        recorder=recorder)
# --> 216         result = transformation(view)
#     217
#     218         artifact = cls.__new__(cls)
#
# /Users/nbokulich/miniconda3/envs/qiime2-06/lib/python3.5/site-packages/qiime-2.0.6-py3.5.egg/qiime/core/transform.py in transformation(view)
#      55         def transformation(view):
#      56             view = self.coerce_view(view)
# ---> 57             self.validate(view)
#      58
#      59             new_view = transformer(view)
#
# /Users/nbokulich/miniconda3/envs/qiime2-06/lib/python3.5/site-packages/qiime-2.0.6-py3.5.egg/qiime/core/transform.py in validate(self, view)
#     112                             % (view, self._view_type))
#     113         # Formats have a validate method, so defer to it
# --> 114         view.validate()
#     115
#     116     def set_user_owned(self, view, value):
#
# /Users/nbokulich/miniconda3/envs/qiime2-06/lib/python3.5/site-packages/qiime-2.0.6-py3.5.egg/qiime/plugin/model/file_format.py in validate(self)
#      29         if not is_member:
#      30             raise ValueError("%r is not formatted as a %s file."
# ---> 31                              % (self.path, self.__class__.__name__))
#      32
#      33
#
# ValueError: InPath('/Users/nbokulich/Desktop/projects/natural_community_priors/wine-final.seqs.fa.no_artifacts.fasta') is not formatted as a DNAFASTAFormat file.

# %%
    ### Collapsing features and tables may be unnecessary for simulation
    ### just randomly sample tax_assign to make simulated sets.
                    
    # collapse features
    # in qiime2, species = level 7
    taxa_table = taxa.methods.collapse(table = feature_table, taxonomy = tax_assign,
                                      level = 7)           
    tax_assign.save(''.join(map(str, [natural_community_dir, '/', 
                                      dataset, '_tax_assignment.qza']))
    # collapse samples

    # store as dict?
                    
    # add to natural_datasets? as dataframe? 
    # Then we can store dataframe and call composition below without re-running this step

# %% [markdown]
# ## Generating simulated communities resembling natural communities
# The purpose of this step is to generate simulated communities that resemble natural sample types, but contain a known taxonomic composition.

# %%
num_samples = 5
seqs_per_sample = 1000

# Select an appropriate reference dataset (RD).
# extract NC sequences x,y,z (match RD taxonomies x,y,z)
# mix x,y,z at defined distributions D to make simulated community S

# %% [markdown]
# ## Classification of simulated communities using prior probabilities

# %%
# provide prior distributions to classifier C
# assign taxonomy to S using C

# %% [markdown]
# ## Classification of natural communities using prior probabilities

# %%
# provide prior distributions to classifier C
# assign taxonomy to NC using C
